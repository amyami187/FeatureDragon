# %% [markdown]
# # This notebook is meant as a tool to monitor the training process

# %%
import os,sys
currentdir = os.getcwd()
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from modules.plot_utils import disp_learn_hist_smoothed

# %%
from IPython import display
import time

# %%
# %matplotlib inline

# %% [markdown]
# You will need to change the location of where these files are

# %%
#loc="../model_state_dumps/20191126_084025/" #reuploading map normalized moons
loc="../model_state_dumps/20191126_105659/" #4 example reuploading map normalized moons no noise"

# %%
iter_lim=30
iter=0
while iter<iter_lim:
    try:
        #for unsmoothed plot
        #fig=plot_utils.disp_learn_hist(loc,losslim=3.0,show=False)
        fig=disp_learn_hist_smoothed(loc,window_val=1,window_train=1,losslim=4.0,show=False)
        display.display(fig)
        display.clear_output(wait=True,)
        time.sleep(10)
        iter+=1
    except KeyboardInterrupt:
        break
